# %% [markdown]
# Imports

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import r2_score

# %%
df = pd.read_csv("jobs_in_data.csv")

# Split the 'salary_in_usd' column by 1000
df['salary_in_usd'] /= 1000


# Calculate the ratio of "salary_in_usd" to "salary"
df['salary_ratio'] = df['salary_in_usd'] / df['salary']


# Map experience levels to ordinal numbers
experience_mapping = {'Entry-level': 1, 'Mid-level': 2, 'Senior': 3, 'Executive': 4}
df['experience_level_encoded'] = df['experience_level'].map(experience_mapping)

# Mapping for 'work_setting'
work_setting_mapping = {'Hybrid': 1, 'In-person': 2, 'Remote': 3}
df['work_setting_encoded'] = df['work_setting'].map(work_setting_mapping)

# Mapping for 'employment_type'
employment_type_mapping = {'Full-time': 1, 'Part-time': 2, 'Contract': 3, 'Freelance': 4}
df['employment_type_encoded'] = df['employment_type'].map(employment_type_mapping)

# Mapping for 'company_size'
company_size_mapping = {'L': 1, 'M': 2, 'S': 3}
df['company_size_encoded'] = df['company_size'].map(company_size_mapping)




# Calculate the percentile rank of each salary within its job category
df['Percentile'] = df.groupby('job_category')['salary'].rank(pct=True)

# Normalize the percentile ranks to a scale of 0 to 1
min_percentile = df['Percentile'].min()
max_percentile = df['Percentile'].max()
df['Normalized_Salary_within_Job_Category'] = (df['Percentile'] - min_percentile) / (max_percentile - min_percentile)

# Drop the temporary 'Percentile' column if you don't need it anymore
df.drop(columns=['Percentile'], inplace=True)

# Define features and target variable
X_numerical = df.select_dtypes(include=np.number).drop(
    columns=["salary_in_usd", "salary"])  # Select only numeric columns
y = df["salary_in_usd"]

# Scale numerical data
scaler = StandardScaler()
X_numerical_scaled = scaler.fit_transform(X_numerical)

# Split data into train and test sets
X_train_num, X_test_num, y_train, y_test = train_test_split(X_numerical_scaled, y, test_size=0.2, random_state=42)

# Reshape the input data to include timestep dimension
X_train_reshaped = X_train_num.reshape(X_train_num.shape[0], X_train_num.shape[1], 1)
X_test_reshaped = X_test_num.reshape(X_test_num.shape[0], X_test_num.shape[1], 1)

# Define LSTM model
input_layer = Input(shape=(X_train_reshaped.shape[1], X_train_reshaped.shape[2]))
lstm_layer = LSTM(128, return_sequences=True)(input_layer)
dropout_layer = Dropout(0.0)(lstm_layer)
lstm_layer2 = LSTM(64)(dropout_layer)
output_layer = Dense(1, activation='linear')(lstm_layer2)
model = Model(inputs=input_layer, outputs=output_layer)

# Compile the model
optimizer = Adam(learning_rate=0.01)
model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mse'])


# Train the model
history = model.fit(X_train_reshaped, y_train, epochs=100, batch_size=64, validation_split=0.1)

# Evaluate the model
y_pred = model.predict(X_test_reshaped)
mse = mean_squared_error(y_test, y_pred)
print("RMSE:", np.sqrt(mse))

# Calculate R-squared (accuracy)
r2 = r2_score(y_test, y_pred)
accuracy = np.round(r2 * 100, 2)
print("Accuracy:", accuracy)

# %%
# 1. Feature Descriptions
print("Feature Descriptions:")
print(df.info())  # Display information about each column (e.g., data type)

# 2. Data Distribution
print("\nData Distribution:")
print(df.describe())  # Display summary statistics for numerical features

# 3. Missing Values
print("\nMissing Values:")
print(df.isnull().sum())  # Count missing values in each column

# 4. Correlation Analysis
print("\nCorrelation Analysis:")
numeric_df = df.select_dtypes(include=['number'])  # Select only numerical columns
correlation_matrix = numeric_df.corr()  # Calculate correlation matrix
print(correlation_matrix)  # Display correlation matrix
# Out:
# Feature Descriptions:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   work_year                              9355 non-null   int64
#  1   job_title                              9355 non-null   object
#  2   job_category                           9355 non-null   object
#  3   salary_currency                        9355 non-null   object
#  4   salary                                 9355 non-null   int64
#  5   salary_in_usd                          9355 non-null   float64
#  6   employee_residence                     9355 non-null   object
#  7   experience_level                       9355 non-null   object
#  8   employment_type                        9355 non-null   object
#  9   work_setting                           9355 non-null   object
#  10  company_location                       9355 non-null   object
#  11  company_size                           9355 non-null   object
#  12  salary_ratio                           9355 non-null   float64
#  13  experience_level_encoded               9355 non-null   int64
#  14  work_setting_encoded                   9355 non-null   int64
#  15  employment_type_encoded                9355 non-null   int64
#  16  company_size_encoded                   9355 non-null   int64
#  17  Normalized_Salary_within_Job_Category  9355 non-null   float64
# dtypes: float64(3), int64(6), object(9)
# memory usage: 1.3+ MB
# None
#
# Data Distribution:
#          work_year         salary  salary_in_usd  salary_ratio  \
# count  9355.000000    9355.000000    9355.000000   9355.000000
# mean   2022.760449  149927.981293     150.299496      0.001009
# std       0.519470   63608.835387      63.177372      0.000063
# min    2020.000000   14000.000000      15.000000      0.000051
# 25%    2023.000000  105200.000000     105.700000      0.001000
# 50%    2023.000000  143860.000000     143.000000      0.001000
# 75%    2023.000000  187000.000000     186.723000      0.001000
# max    2023.000000  450000.000000     450.000000      0.001375
#
#        experience_level_encoded  work_setting_encoded  \
# count               9355.000000           9355.000000
# mean                   2.724212              2.346660
# std                    0.604882              0.517058
# min                    1.000000              1.000000
# 25%                    2.000000              2.000000
# 50%                    3.000000              2.000000
# 75%                    3.000000              3.000000
# max                    4.000000              3.000000
#
#        employment_type_encoded  company_size_encoded  \
# count              9355.000000           9355.000000
# mean                  1.009193              1.937039
# std                   0.142224              0.304958
# min                   1.000000              1.000000
# 25%                   1.000000              2.000000
# 50%                   1.000000              2.000000
# 75%                   1.000000              2.000000
# max                   4.000000              3.000000
#
#        Normalized_Salary_within_Job_Category
# count                            9355.000000
# mean                                0.500369
# std                                 0.288761
# min                                 0.000000
# 25%                                 0.250913
# 50%                                 0.500664
# 75%                                 0.751688
# max                                 1.000000
#
# Missing Values:
# work_year                                0
# job_title                                0
# job_category                             0
# salary_currency                          0
# salary                                   0
# salary_in_usd                            0
# employee_residence                       0
# experience_level                         0
# employment_type                          0
# work_setting                             0
# company_location                         0
# company_size                             0
# salary_ratio                             0
# experience_level_encoded                 0
# work_setting_encoded                     0
# employment_type_encoded                  0
# company_size_encoded                     0
# Normalized_Salary_within_Job_Category    0
# dtype: int64
#
# Correlation Analysis:
#                                        work_year    salary  salary_in_usd  \
# work_year                               1.000000  0.160708       0.166003
# salary                                  0.160708  1.000000       0.991309
# salary_in_usd                           0.166003  0.991309       1.000000
# salary_ratio                           -0.051012 -0.245402      -0.138024
# experience_level_encoded                0.138119  0.373014       0.373559
# work_setting_encoded                   -0.068513 -0.019304      -0.021230
# employment_type_encoded                -0.106208 -0.064424      -0.069364
# company_size_encoded                    0.112634 -0.021408      -0.014439
# Normalized_Salary_within_Job_Category   0.152216  0.891145       0.882384
#
#                                        salary_ratio  experience_level_encoded  \
# work_year                                 -0.051012                  0.138119
# salary                                    -0.245402                  0.373014
# salary_in_usd                             -0.138024                  0.373559
# salary_ratio                               1.000000                 -0.108003
# experience_level_encoded                  -0.108003                  1.000000
# work_setting_encoded                      -0.035991                  0.062683
# employment_type_encoded                   -0.039762                 -0.079882
# company_size_encoded                       0.052455                  0.031041
# Normalized_Salary_within_Job_Category     -0.246584                  0.366245
#
#                                        work_setting_encoded  \
# work_year                                         -0.068513
# salary                                            -0.019304
# salary_in_usd                                     -0.021230
# salary_ratio                                      -0.035991
# experience_level_encoded                           0.062683
# work_setting_encoded                               1.000000
# employment_type_encoded                            0.011902
# company_size_encoded                               0.088940
# Normalized_Salary_within_Job_Category              0.020256
#
#                                        employment_type_encoded  \
# work_year                                            -0.106208
# salary                                               -0.064424
# salary_in_usd                                        -0.069364
# salary_ratio                                         -0.039762
# experience_level_encoded                             -0.079882
# work_setting_encoded                                  0.011902
# employment_type_encoded                               1.000000
# company_size_encoded                                  0.047854
# Normalized_Salary_within_Job_Category                -0.070409
#
#                                        company_size_encoded  \
# work_year                                          0.112634
# salary                                            -0.021408
# salary_in_usd                                     -0.014439
# salary_ratio                                       0.052455
# experience_level_encoded                           0.031041
# work_setting_encoded                               0.088940
# employment_type_encoded                            0.047854
# company_size_encoded                               1.000000
# Normalized_Salary_within_Job_Category             -0.002657
#
#                                        Normalized_Salary_within_Job_Category
# work_year                                                           0.152216
# salary                                                              0.891145
# salary_in_usd                                                       0.882384
# salary_ratio                                                       -0.246584
# experience_level_encoded                                            0.366245
# work_setting_encoded                                                0.020256
# employment_type_encoded                                            -0.070409
# company_size_encoded                                               -0.002657
# Normalized_Salary_within_Job_Category                               1.000000
